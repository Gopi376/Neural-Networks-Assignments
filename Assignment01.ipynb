# %%
#Question 01 A:

st = input()
st = st[:1]+st[2:]  #Removes 2nd character from the string(Slicing the string and attaching again)
st = st[:1]+st[2:]
st = st[::-1]       #Rverse the string
print(st)
# Out:
# PYTHON
# NOHP

# %%
#Question 01 B

x = int(input())
y = int(input())
print("Addition of two numbers : " , x+y)
print("Subtraction of two numbers : " , x-y)
print("Division of two numbers : " , x/y)
print("Multiplication of two numbers : ",x*y)
# Out:
# 25
# 85
# Addition of two numbers :  110
# Subtraction of two numbers :  -60
# Division of two numbers :  0.29411764705882354
# Multiplication of two numbers :  2125

# %%
#Question 02

st = input()
st_1 = "python"
st_2 = "pythons"
st = st.replace(st_1,st_2)  # It is a inbuilt fuction which replaces substring st_1 with substring st_2
print(st)
# Out:
# python is good
# pythons is good

# %%
#Question 03

x = int(input())
if x >=90:
    print("Grade A")
elif x>=80:
    print("Grade B")
elif x>=70:
    print("Grade C")
elif x>=60 :
    print("Grade D")
elif x :
    print("Grade F")
# Out:
# 78
# Grade C
